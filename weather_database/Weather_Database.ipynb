# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Deliverable 1.3: Create a new set of 2000 random lat & long
#create a set of random latitue and longitude combinations
#zip creates a tuple of the respective index for lat and lngs
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high = 180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

#add coordinates to a list
coordinates=list(lat_lngs)

# %%
# Deliverable 1.4: Get the nearest city using the citypy module
# # Create a list for holding the cities
cities=[]
#identify the nearest city for each latititude and longitude combo

for coordinate in coordinates:
    city= citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #if the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)

#print the city count to confirm sufficient count
len(cities)
# Out:
# 747

# %%
#Deliverable 1.5: Perform an API call with the OpenWeatherMap
#import requests library
import requests

#import API key
from config import weather_api_key


# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# cities

# %%
#6.2.6 Get the city weather


#create an empty list to hold the weather data
city_data = []

#print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
#         # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | felanitx
# Processing Record 4 of Set 1 | san luis
# Processing Record 5 of Set 1 | biak
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | bambous virieux
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | benito juarez
# Processing Record 12 of Set 1 | pangody
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | puro
# Processing Record 16 of Set 1 | waipawa
# Processing Record 17 of Set 1 | lososina
# Processing Record 18 of Set 1 | benicarlo
# Processing Record 19 of Set 1 | sao filipe
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | san patricio
# Processing Record 22 of Set 1 | taksimo
# Processing Record 23 of Set 1 | zile
# Processing Record 24 of Set 1 | saint anthony
# Processing Record 25 of Set 1 | namibe
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | pacific grove
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 33 of Set 1 | doha
# Processing Record 34 of Set 1 | bahia honda
# Processing Record 35 of Set 1 | lavrentiya
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | abonnema
# Processing Record 39 of Set 1 | san rafael
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | la ronge
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | cidreira
# Processing Record 45 of Set 1 | airai
# Processing Record 46 of Set 1 | okhotsk
# Processing Record 47 of Set 1 | timmins
# Processing Record 48 of Set 1 | zeya
# Processing Record 49 of Set 1 | waitati
# Processing Record 50 of Set 1 | gazojak
# Processing Record 1 of Set 2 | ukiah
# Processing Record 2 of Set 2 | havre-saint-pierre
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | sao joao da barra
# Processing Record 6 of Set 2 | maungatapere
# Processing Record 7 of Set 2 | riachao
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | port elizabeth
# Processing Record 11 of Set 2 | kaitangata
# Processing Record 12 of Set 2 | santa vitoria do palmar
# Processing Record 13 of Set 2 | grand gaube
# Processing Record 14 of Set 2 | namatanai
# Processing Record 15 of Set 2 | aykhal
# Processing Record 16 of Set 2 | severo-kurilsk
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | fortuna
# Processing Record 19 of Set 2 | watsa
# Processing Record 20 of Set 2 | sioux lookout
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | pozo colorado
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | port moresby
# Processing Record 27 of Set 2 | richards bay
# Processing Record 28 of Set 2 | avera
# Processing Record 29 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 2 | tuatapere
# Processing Record 31 of Set 2 | naze
# Processing Record 32 of Set 2 | nenjiang
# Processing Record 33 of Set 2 | vetapalem
# Processing Record 34 of Set 2 | talnakh
# Processing Record 35 of Set 2 | george town
# Processing Record 36 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 2 | arlit
# Processing Record 38 of Set 2 | katsuura
# Processing Record 39 of Set 2 | chokurdakh
# Processing Record 40 of Set 2 | miami
# Processing Record 41 of Set 2 | novo aripuana
# Processing Record 42 of Set 2 | vage
# Processing Record 43 of Set 2 | bredasdorp
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | praxedis guerrero
# Processing Record 46 of Set 2 | chapais
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | surgut
# Processing Record 49 of Set 2 | yulara
# Processing Record 50 of Set 2 | ambon
# Processing Record 1 of Set 3 | tianpeng
# Processing Record 2 of Set 3 | mahebourg
# Processing Record 3 of Set 3 | nhulunbuy
# Processing Record 4 of Set 3 | silver city
# Processing Record 5 of Set 3 | dalvik
# Processing Record 6 of Set 3 | lensk
# Processing Record 7 of Set 3 | arraial do cabo
# Processing Record 8 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 3 | segou
# Processing Record 12 of Set 3 | hithadhoo
# Processing Record 13 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 14 of Set 3 | coahuayana
# Processing Record 15 of Set 3 | arman
# Processing Record 16 of Set 3 | yankton
# Processing Record 17 of Set 3 | hobart
# Processing Record 18 of Set 3 | cockburn town
# Processing Record 19 of Set 3 | crofton
# Processing Record 20 of Set 3 | geraldton
# Processing Record 21 of Set 3 | barrow
# Processing Record 22 of Set 3 | miquelon
# Processing Record 23 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | araouane
# Processing Record 26 of Set 3 | batagay-alyta
# Processing Record 27 of Set 3 | riverton
# Processing Record 28 of Set 3 | souillac
# Processing Record 29 of Set 3 | maryville
# Processing Record 30 of Set 3 | nome
# Processing Record 31 of Set 3 | tuktoyaktuk
# Processing Record 32 of Set 3 | canutama
# Processing Record 33 of Set 3 | segezha
# Processing Record 34 of Set 3 | lasa
# Processing Record 35 of Set 3 | awbari
# Processing Record 36 of Set 3 | nishihara
# Processing Record 37 of Set 3 | ola
# Processing Record 38 of Set 3 | cherskiy
# Processing Record 39 of Set 3 | punta arenas
# Processing Record 40 of Set 3 | ilulissat
# Processing Record 41 of Set 3 | kruisfontein
# Processing Record 42 of Set 3 | andenes
# Processing Record 43 of Set 3 | longyearbyen
# Processing Record 44 of Set 3 | half moon bay
# Processing Record 45 of Set 3 | lianran
# Processing Record 46 of Set 3 | dingle
# Processing Record 47 of Set 3 | isangel
# Processing Record 48 of Set 3 | berlevag
# Processing Record 49 of Set 3 | bonfim
# Processing Record 50 of Set 3 | verkhoyansk
# Processing Record 1 of Set 4 | coshocton
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | arcata
# Processing Record 4 of Set 4 | fayaoue
# Processing Record 5 of Set 4 | soe
# Processing Record 6 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 4 | novoilinsk
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | loralai
# Processing Record 10 of Set 4 | hilo
# Processing Record 11 of Set 4 | iqaluit
# Processing Record 12 of Set 4 | broome
# Processing Record 13 of Set 4 | lompoc
# Processing Record 14 of Set 4 | chipinge
# Processing Record 15 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 4 | englehart
# Processing Record 17 of Set 4 | san policarpo
# Processing Record 18 of Set 4 | maniitsoq
# Processing Record 19 of Set 4 | komsomolskiy
# Processing Record 20 of Set 4 | narsaq
# Processing Record 21 of Set 4 | mnogovershinnyy
# Processing Record 22 of Set 4 | payson
# Processing Record 23 of Set 4 | catamarca
# Processing Record 24 of Set 4 | tangua
# Processing Record 25 of Set 4 | bakchar
# Processing Record 26 of Set 4 | luderitz
# Processing Record 27 of Set 4 | lebu
# Processing Record 28 of Set 4 | provideniya
# Processing Record 29 of Set 4 | cordoba
# Processing Record 30 of Set 4 | lusambo
# Processing Record 31 of Set 4 | whitehorse
# Processing Record 32 of Set 4 | te anau
# Processing Record 33 of Set 4 | bandarbeyla
# Processing Record 34 of Set 4 | ambilobe
# Processing Record 35 of Set 4 | esperance
# Processing Record 36 of Set 4 | georgetown
# Processing Record 37 of Set 4 | chittaurgarh
# Processing Record 38 of Set 4 | mezhdurechensk
# Processing Record 39 of Set 4 | muroto
# Processing Record 40 of Set 4 | irece
# Processing Record 41 of Set 4 | siocon
# Processing Record 42 of Set 4 | port hardy
# Processing Record 43 of Set 4 | kargil
# Processing Record 44 of Set 4 | fort nelson
# Processing Record 45 of Set 4 | khasan
# Processing Record 46 of Set 4 | puerto ayacucho
# Processing Record 47 of Set 4 | beloha
# Processing Record 48 of Set 4 | vincennes
# Processing Record 49 of Set 4 | beisfjord
# Processing Record 50 of Set 4 | tilichiki
# Processing Record 1 of Set 5 | caravelas
# Processing Record 2 of Set 5 | salaga
# Processing Record 3 of Set 5 | shaunavon
# Processing Record 4 of Set 5 | cayenne
# Processing Record 5 of Set 5 | yandoon
# City not found. Skipping...
# Processing Record 6 of Set 5 | zhigansk
# Processing Record 7 of Set 5 | omsukchan
# Processing Record 8 of Set 5 | lagoa
# Processing Record 9 of Set 5 | iquitos
# Processing Record 10 of Set 5 | auki
# Processing Record 11 of Set 5 | camopi
# Processing Record 12 of Set 5 | roebourne
# Processing Record 13 of Set 5 | mount gambier
# Processing Record 14 of Set 5 | abaza
# Processing Record 15 of Set 5 | tvedestrand
# Processing Record 16 of Set 5 | tasiilaq
# Processing Record 17 of Set 5 | moose factory
# Processing Record 18 of Set 5 | lahaina
# Processing Record 19 of Set 5 | athabasca
# Processing Record 20 of Set 5 | jambi
# Processing Record 21 of Set 5 | haines junction
# Processing Record 22 of Set 5 | hun
# Processing Record 23 of Set 5 | grand-lahou
# Processing Record 24 of Set 5 | olafsvik
# Processing Record 25 of Set 5 | nikolskoye
# Processing Record 26 of Set 5 | kavieng
# Processing Record 27 of Set 5 | westport
# Processing Record 28 of Set 5 | wuxi
# Processing Record 29 of Set 5 | ponta do sol
# Processing Record 30 of Set 5 | nabire
# Processing Record 31 of Set 5 | sept-iles
# Processing Record 32 of Set 5 | kismayo
# Processing Record 33 of Set 5 | quelimane
# Processing Record 34 of Set 5 | cururupu
# Processing Record 35 of Set 5 | bereda
# Processing Record 36 of Set 5 | udachnyy
# Processing Record 37 of Set 5 | victoria
# Processing Record 38 of Set 5 | polunochnoye
# Processing Record 39 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 5 | inhambane
# Processing Record 41 of Set 5 | kokopo
# Processing Record 42 of Set 5 | pokaran
# Processing Record 43 of Set 5 | christchurch
# Processing Record 44 of Set 5 | kalat
# Processing Record 45 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | hrubieszow
# Processing Record 48 of Set 5 | lethem
# Processing Record 49 of Set 5 | saint george
# Processing Record 50 of Set 5 | ribeira grande
# Processing Record 1 of Set 6 | marsh harbour
# Processing Record 2 of Set 6 | kletskaya
# Processing Record 3 of Set 6 | mormugao
# Processing Record 4 of Set 6 | asau
# Processing Record 5 of Set 6 | moshkovo
# Processing Record 6 of Set 6 | severo-yeniseyskiy
# Processing Record 7 of Set 6 | sumbe
# Processing Record 8 of Set 6 | vestmannaeyjar
# Processing Record 9 of Set 6 | khanpur
# Processing Record 10 of Set 6 | san cristobal
# Processing Record 11 of Set 6 | lewiston
# Processing Record 12 of Set 6 | baoqing
# Processing Record 13 of Set 6 | amahai
# Processing Record 14 of Set 6 | saint-pierre
# Processing Record 15 of Set 6 | council bluffs
# Processing Record 16 of Set 6 | iralaya
# Processing Record 17 of Set 6 | bonthe
# Processing Record 18 of Set 6 | jasper
# Processing Record 19 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 6 | shanghai
# Processing Record 21 of Set 6 | porto belo
# Processing Record 22 of Set 6 | beringovskiy
# Processing Record 23 of Set 6 | manggar
# Processing Record 24 of Set 6 | adre
# Processing Record 25 of Set 6 | bengkulu
# Processing Record 26 of Set 6 | ostrovnoy
# Processing Record 27 of Set 6 | plouzane
# Processing Record 28 of Set 6 | west bay
# Processing Record 29 of Set 6 | hamilton
# Processing Record 30 of Set 6 | salalah
# Processing Record 31 of Set 6 | ponta delgada
# Processing Record 32 of Set 6 | ouadda
# Processing Record 33 of Set 6 | tanda
# Processing Record 34 of Set 6 | aswan
# Processing Record 35 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 6 | natchez
# Processing Record 37 of Set 6 | faya
# Processing Record 38 of Set 6 | onoda
# Processing Record 39 of Set 6 | vardo
# Processing Record 40 of Set 6 | jiwani
# Processing Record 41 of Set 6 | paamiut
# Processing Record 42 of Set 6 | kargasok
# Processing Record 43 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 6 | malakal
# Processing Record 45 of Set 6 | marsa matruh
# Processing Record 46 of Set 6 | carnarvon
# Processing Record 47 of Set 6 | imeni poliny osipenko
# Processing Record 48 of Set 6 | mehamn
# Processing Record 49 of Set 6 | mozelos
# Processing Record 50 of Set 6 | redlands
# Processing Record 1 of Set 7 | fairbanks
# Processing Record 2 of Set 7 | sola
# Processing Record 3 of Set 7 | mayo
# Processing Record 4 of Set 7 | faanui
# Processing Record 5 of Set 7 | flinders
# Processing Record 6 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 7 of Set 7 | odweyne
# Processing Record 8 of Set 7 | ascension
# Processing Record 9 of Set 7 | ochakiv
# Processing Record 10 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 7 | constitucion
# Processing Record 12 of Set 7 | laguna
# Processing Record 13 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 7 | choix
# Processing Record 15 of Set 7 | hambantota
# Processing Record 16 of Set 7 | goderich
# Processing Record 17 of Set 7 | wardha
# Processing Record 18 of Set 7 | innisfail
# Processing Record 19 of Set 7 | naryan-mar
# Processing Record 20 of Set 7 | ossora
# Processing Record 21 of Set 7 | pochinki
# Processing Record 22 of Set 7 | oxford
# Processing Record 23 of Set 7 | shubarshi
# Processing Record 24 of Set 7 | chuy
# Processing Record 25 of Set 7 | caluquembe
# Processing Record 26 of Set 7 | luanda
# Processing Record 27 of Set 7 | bubaque
# Processing Record 28 of Set 7 | mackay
# Processing Record 29 of Set 7 | seoni
# Processing Record 30 of Set 7 | zhanaozen
# Processing Record 31 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 7 | mayor pablo lagerenza
# Processing Record 33 of Set 7 | vila velha
# Processing Record 34 of Set 7 | saint-augustin
# Processing Record 35 of Set 7 | hirara
# Processing Record 36 of Set 7 | yumen
# Processing Record 37 of Set 7 | luocheng
# Processing Record 38 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 40 of Set 7 | songjianghe
# Processing Record 41 of Set 7 | klaksvik
# Processing Record 42 of Set 7 | college
# Processing Record 43 of Set 7 | bull savanna
# Processing Record 44 of Set 7 | nouadhibou
# Processing Record 45 of Set 7 | daxian
# City not found. Skipping...
# Processing Record 46 of Set 7 | hobyo
# Processing Record 47 of Set 7 | yerofey pavlovich
# Processing Record 48 of Set 7 | van
# Processing Record 49 of Set 7 | finschhafen
# Processing Record 50 of Set 7 | labuan
# Processing Record 1 of Set 8 | santa isabel do rio negro
# Processing Record 2 of Set 8 | fremont
# Processing Record 3 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 8 | impfondo
# Processing Record 5 of Set 8 | aklavik
# Processing Record 6 of Set 8 | eureka
# Processing Record 7 of Set 8 | chupa
# Processing Record 8 of Set 8 | nemuro
# Processing Record 9 of Set 8 | sitka
# Processing Record 10 of Set 8 | dhidhdhoo
# Processing Record 11 of Set 8 | hami
# Processing Record 12 of Set 8 | urucui
# Processing Record 13 of Set 8 | kokkola
# Processing Record 14 of Set 8 | itupiranga
# Processing Record 15 of Set 8 | praya
# Processing Record 16 of Set 8 | otavi
# Processing Record 17 of Set 8 | wenling
# Processing Record 18 of Set 8 | sorong
# Processing Record 19 of Set 8 | rodopolis
# Processing Record 20 of Set 8 | usinsk
# Processing Record 21 of Set 8 | grindavik
# Processing Record 22 of Set 8 | saint pete beach
# Processing Record 23 of Set 8 | vao
# Processing Record 24 of Set 8 | kenora
# Processing Record 25 of Set 8 | touros
# Processing Record 26 of Set 8 | dombarovskiy
# Processing Record 27 of Set 8 | omboue
# Processing Record 28 of Set 8 | los llanos de aridane
# Processing Record 29 of Set 8 | sangar
# Processing Record 30 of Set 8 | kupino
# Processing Record 31 of Set 8 | lata
# Processing Record 32 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 33 of Set 8 | sinnamary
# Processing Record 34 of Set 8 | zaragoza
# Processing Record 35 of Set 8 | dinguiraye
# Processing Record 36 of Set 8 | hualmay
# Processing Record 37 of Set 8 | boa vista
# Processing Record 38 of Set 8 | pevek
# Processing Record 39 of Set 8 | codrington
# Processing Record 40 of Set 8 | malindi
# Processing Record 41 of Set 8 | umm kaddadah
# Processing Record 42 of Set 8 | koungheul
# Processing Record 43 of Set 8 | lipari
# Processing Record 44 of Set 8 | shenjiamen
# Processing Record 45 of Set 8 | maunabo
# Processing Record 46 of Set 8 | kiama
# Processing Record 47 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 8 | bilma
# Processing Record 49 of Set 8 | itaituba
# Processing Record 50 of Set 8 | reconquista
# Processing Record 1 of Set 9 | darhan
# Processing Record 2 of Set 9 | bumba
# Processing Record 3 of Set 9 | kanel
# Processing Record 4 of Set 9 | cherat
# Processing Record 5 of Set 9 | gueugnon
# Processing Record 6 of Set 9 | lodja
# Processing Record 7 of Set 9 | sooke
# Processing Record 8 of Set 9 | rio grande
# Processing Record 9 of Set 9 | samarai
# Processing Record 10 of Set 9 | bilkha
# Processing Record 11 of Set 9 | katherine
# Processing Record 12 of Set 9 | kuva
# City not found. Skipping...
# Processing Record 13 of Set 9 | liverpool
# Processing Record 14 of Set 9 | kisangani
# Processing Record 15 of Set 9 | morro bay
# Processing Record 16 of Set 9 | trinidad
# Processing Record 17 of Set 9 | palmer
# Processing Record 18 of Set 9 | tonantins
# Processing Record 19 of Set 9 | bonito
# Processing Record 20 of Set 9 | gat
# Processing Record 21 of Set 9 | alofi
# Processing Record 22 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 9 | chicama
# Processing Record 24 of Set 9 | henties bay
# Processing Record 25 of Set 9 | kyra
# Processing Record 26 of Set 9 | skoghall
# Processing Record 27 of Set 9 | amot
# Processing Record 28 of Set 9 | ketchikan
# Processing Record 29 of Set 9 | sheopur
# Processing Record 30 of Set 9 | kantang
# Processing Record 31 of Set 9 | fairborn
# Processing Record 32 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 9 | ishigaki
# Processing Record 34 of Set 9 | plettenberg bay
# Processing Record 35 of Set 9 | mangai
# Processing Record 36 of Set 9 | kibala
# Processing Record 37 of Set 9 | smithers
# Processing Record 38 of Set 9 | daru
# Processing Record 39 of Set 9 | mendota heights
# Processing Record 40 of Set 9 | ous
# Processing Record 41 of Set 9 | anchorage
# Processing Record 42 of Set 9 | santa ines
# Processing Record 43 of Set 9 | norman wells
# Processing Record 44 of Set 9 | severodvinsk
# Processing Record 45 of Set 9 | celestun
# Processing Record 46 of Set 9 | comodoro rivadavia
# Processing Record 47 of Set 9 | langnau
# Processing Record 48 of Set 9 | ahipara
# Processing Record 49 of Set 9 | payo
# Processing Record 50 of Set 9 | uryupinsk
# Processing Record 1 of Set 10 | mecca
# Processing Record 2 of Set 10 | agadir
# Processing Record 3 of Set 10 | stornoway
# Processing Record 4 of Set 10 | acapulco
# Processing Record 5 of Set 10 | byron bay
# Processing Record 6 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 10 | druzhnaya gorka
# Processing Record 8 of Set 10 | blackwater
# Processing Record 9 of Set 10 | kitimat
# Processing Record 10 of Set 10 | baykit
# Processing Record 11 of Set 10 | victoria point
# Processing Record 12 of Set 10 | ajaccio
# Processing Record 13 of Set 10 | urumqi
# Processing Record 14 of Set 10 | nuuk
# Processing Record 15 of Set 10 | wajima
# Processing Record 16 of Set 10 | lingao
# Processing Record 17 of Set 10 | yar-sale
# Processing Record 18 of Set 10 | kirakira
# Processing Record 19 of Set 10 | moyo
# Processing Record 20 of Set 10 | palana
# Processing Record 21 of Set 10 | dunkirk
# Processing Record 22 of Set 10 | high level
# Processing Record 23 of Set 10 | dzerzhinsk
# Processing Record 24 of Set 10 | batagay
# Processing Record 25 of Set 10 | aitape
# Processing Record 26 of Set 10 | lithia springs
# Processing Record 27 of Set 10 | tevriz
# Processing Record 28 of Set 10 | port blair
# Processing Record 29 of Set 10 | bay roberts
# Processing Record 30 of Set 10 | molchanovo
# Processing Record 31 of Set 10 | meadow lake
# Processing Record 32 of Set 10 | barabinsk
# Processing Record 33 of Set 10 | lukulu
# Processing Record 34 of Set 10 | turukhansk
# Processing Record 35 of Set 10 | zambezi
# Processing Record 36 of Set 10 | chabahar
# Processing Record 37 of Set 10 | juatuba
# Processing Record 38 of Set 10 | gushikawa
# Processing Record 39 of Set 10 | bassar
# Processing Record 40 of Set 10 | suhbaatar
# Processing Record 41 of Set 10 | novikovo
# Processing Record 42 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 10 | leopoldov
# Processing Record 44 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 45 of Set 10 | mopti
# Processing Record 46 of Set 10 | boden
# Processing Record 47 of Set 10 | baherden
# Processing Record 48 of Set 10 | elko
# Processing Record 49 of Set 10 | moree
# Processing Record 50 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 11 | padang
# Processing Record 2 of Set 11 | cabo san lucas
# Processing Record 3 of Set 11 | ranong
# Processing Record 4 of Set 11 | anadyr
# Processing Record 5 of Set 11 | urusha
# Processing Record 6 of Set 11 | gobabis
# Processing Record 7 of Set 11 | laramie
# Processing Record 8 of Set 11 | pangnirtung
# Processing Record 9 of Set 11 | lazarev
# Processing Record 10 of Set 11 | necochea
# Processing Record 11 of Set 11 | lokosovo
# Processing Record 12 of Set 11 | ostersund
# Processing Record 13 of Set 11 | kinston
# Processing Record 14 of Set 11 | karratha
# Processing Record 15 of Set 11 | port shepstone
# Processing Record 16 of Set 11 | mandera
# Processing Record 17 of Set 11 | kavaratti
# Processing Record 18 of Set 11 | porto santo
# Processing Record 19 of Set 11 | pisco
# Processing Record 20 of Set 11 | catalao
# Processing Record 21 of Set 11 | coihaique
# Processing Record 22 of Set 11 | sao miguel do araguaia
# Processing Record 23 of Set 11 | noumea
# Processing Record 24 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 11 | road town
# Processing Record 26 of Set 11 | sisimiut
# Processing Record 27 of Set 11 | vanderhoof
# Processing Record 28 of Set 11 | bambanglipuro
# Processing Record 29 of Set 11 | alice
# Processing Record 30 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 11 | sorland
# Processing Record 32 of Set 11 | selma
# Processing Record 33 of Set 11 | litherland
# Processing Record 34 of Set 11 | guerrero negro
# Processing Record 35 of Set 11 | buluang
# Processing Record 36 of Set 11 | portland
# Processing Record 37 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 11 | porto novo
# Processing Record 39 of Set 11 | tommot
# Processing Record 40 of Set 11 | wanning
# Processing Record 41 of Set 11 | vila
# Processing Record 42 of Set 11 | kilcormac
# Processing Record 43 of Set 11 | prince rupert
# Processing Record 44 of Set 11 | bol
# Processing Record 45 of Set 11 | vuktyl
# Processing Record 46 of Set 11 | santa pola
# Processing Record 47 of Set 11 | kerema
# Processing Record 48 of Set 11 | bobo dioulasso
# Processing Record 49 of Set 11 | saint-francois
# Processing Record 50 of Set 11 | muromtsevo
# Processing Record 1 of Set 12 | naushki
# Processing Record 2 of Set 12 | mujiayingzi
# Processing Record 3 of Set 12 | bang saphan
# Processing Record 4 of Set 12 | yarim
# Processing Record 5 of Set 12 | hay river
# Processing Record 6 of Set 12 | ancud
# Processing Record 7 of Set 12 | muratbey
# Processing Record 8 of Set 12 | preobrazheniye
# Processing Record 9 of Set 12 | hofn
# Processing Record 10 of Set 12 | meulaboh
# Processing Record 11 of Set 12 | mustasaari
# Processing Record 12 of Set 12 | upernavik
# Processing Record 13 of Set 12 | diriamba
# Processing Record 14 of Set 12 | avsyunino
# Processing Record 15 of Set 12 | teacapan
# Processing Record 16 of Set 12 | nacala
# Processing Record 17 of Set 12 | mount pleasant
# Processing Record 18 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 19 of Set 12 | lorengau
# Processing Record 20 of Set 12 | arrecife
# Processing Record 21 of Set 12 | arona
# Processing Record 22 of Set 12 | el higo
# Processing Record 23 of Set 12 | griffith
# Processing Record 24 of Set 12 | kannod
# Processing Record 25 of Set 12 | bulaevo
# Processing Record 26 of Set 12 | kutum
# Processing Record 27 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 12 | tshikapa
# Processing Record 29 of Set 12 | deputatskiy
# Processing Record 30 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 31 of Set 12 | tombouctou
# Processing Record 32 of Set 12 | puerto escondido
# Processing Record 33 of Set 12 | herat
# Processing Record 34 of Set 12 | huaral
# Processing Record 35 of Set 12 | bagdarin
# Processing Record 36 of Set 12 | wakiso
# Processing Record 37 of Set 12 | port macquarie
# Processing Record 38 of Set 12 | belaya gora
# Processing Record 39 of Set 12 | san juan
# Processing Record 40 of Set 12 | vire
# Processing Record 41 of Set 12 | kasamwa
# Processing Record 42 of Set 12 | santa marta
# Processing Record 43 of Set 12 | langenburg
# Processing Record 44 of Set 12 | port keats
# Processing Record 45 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 12 | gao
# Processing Record 47 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 48 of Set 12 | carahue
# Processing Record 49 of Set 12 | tongchuan
# Processing Record 50 of Set 12 | maragogi
# Processing Record 1 of Set 13 | havoysund
# Processing Record 2 of Set 13 | krapivinskiy
# Processing Record 3 of Set 13 | tiznit
# Processing Record 4 of Set 13 | astoria
# Processing Record 5 of Set 13 | jumla
# Processing Record 6 of Set 13 | ngunguru
# Processing Record 7 of Set 13 | mouzakion
# City not found. Skipping...
# Processing Record 8 of Set 13 | tutoia
# Processing Record 9 of Set 13 | waw
# Processing Record 10 of Set 13 | haukipudas
# Processing Record 11 of Set 13 | onufriyivka
# Processing Record 12 of Set 13 | walvis bay
# Processing Record 13 of Set 13 | mbour
# Processing Record 14 of Set 13 | boffa
# Processing Record 15 of Set 13 | uarini
# Processing Record 16 of Set 13 | saint-leu
# Processing Record 17 of Set 13 | manadhoo
# Processing Record 18 of Set 13 | harlingen
# Processing Record 19 of Set 13 | moron
# Processing Record 20 of Set 13 | porto recanati
# Processing Record 21 of Set 13 | rhyl
# Processing Record 22 of Set 13 | sobral
# Processing Record 23 of Set 13 | vila do maio
# Processing Record 24 of Set 13 | krasnoye
# Processing Record 25 of Set 13 | kenai
# Processing Record 26 of Set 13 | chulym
# Processing Record 27 of Set 13 | acaponeta
# Processing Record 28 of Set 13 | parrita
# Processing Record 29 of Set 13 | tyachiv
# Processing Record 30 of Set 13 | neya
# Processing Record 31 of Set 13 | shimoda
# Processing Record 32 of Set 13 | kosino
# Processing Record 33 of Set 13 | buin
# Processing Record 34 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 13 | ulaangom
# Processing Record 37 of Set 13 | aksarka
# Processing Record 38 of Set 13 | niagara falls
# Processing Record 39 of Set 13 | limenaria
# Processing Record 40 of Set 13 | farah
# Processing Record 41 of Set 13 | liaocheng
# Processing Record 42 of Set 13 | vila franca do campo
# Processing Record 43 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 44 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 45 of Set 13 | arandis
# Processing Record 46 of Set 13 | grayvoron
# Processing Record 47 of Set 13 | salina cruz
# Processing Record 48 of Set 13 | calvinia
# Processing Record 49 of Set 13 | dunedin
# Processing Record 50 of Set 13 | labuhan
# Processing Record 1 of Set 14 | staryy nadym
# Processing Record 2 of Set 14 | urengoy
# Processing Record 3 of Set 14 | goya
# Processing Record 4 of Set 14 | sibolga
# Processing Record 5 of Set 14 | lazaro cardenas
# Processing Record 6 of Set 14 | ko samui
# Processing Record 7 of Set 14 | rocky mountain house
# Processing Record 8 of Set 14 | coswig
# Processing Record 9 of Set 14 | makat
# Processing Record 10 of Set 14 | kahului
# Processing Record 11 of Set 14 | dwarka
# Processing Record 12 of Set 14 | piet retief
# Processing Record 13 of Set 14 | blandiana
# Processing Record 14 of Set 14 | mangualde
# Processing Record 15 of Set 14 | pouebo
# Processing Record 16 of Set 14 | pocosol
# Processing Record 17 of Set 14 | nanakuli
# Processing Record 18 of Set 14 | jining
# Processing Record 19 of Set 14 | bud
# Processing Record 20 of Set 14 | poso
# Processing Record 21 of Set 14 | lima
# Processing Record 22 of Set 14 | huangnihe
# Processing Record 23 of Set 14 | montrose
# Processing Record 24 of Set 14 | alta floresta
# Processing Record 25 of Set 14 | leo
# Processing Record 26 of Set 14 | matagami
# Processing Record 27 of Set 14 | fare
# Processing Record 28 of Set 14 | sambava
# Processing Record 29 of Set 14 | plaster rock
# Processing Record 30 of Set 14 | xingyi
# Processing Record 31 of Set 14 | tura
# Processing Record 32 of Set 14 | bairiki
# Processing Record 33 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 14 | mondeville
# Processing Record 35 of Set 14 | antofagasta
# Processing Record 36 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 37 of Set 14 | kanata
# Processing Record 38 of Set 14 | tiarei
# Processing Record 39 of Set 14 | san ramon
# Processing Record 40 of Set 14 | tongliao
# Processing Record 41 of Set 14 | kyren
# Processing Record 42 of Set 14 | rabo de peixe
# Processing Record 43 of Set 14 | ipilan
# Processing Record 44 of Set 14 | storm lake
# Processing Record 45 of Set 14 | stephenville
# Processing Record 46 of Set 14 | soyo
# Processing Record 47 of Set 14 | aripuana
# Processing Record 48 of Set 14 | astara
# Processing Record 49 of Set 14 | taltal
# Processing Record 50 of Set 14 | emerald
# Processing Record 1 of Set 15 | saint stephen
# Processing Record 2 of Set 15 | kimbe
# Processing Record 3 of Set 15 | lavumisa
# Processing Record 4 of Set 15 | gornopravdinsk
# Processing Record 5 of Set 15 | ligayan
# Processing Record 6 of Set 15 | hervey bay
# Processing Record 7 of Set 15 | alta
# Processing Record 8 of Set 15 | sur
# Processing Record 9 of Set 15 | wattegama
# Processing Record 10 of Set 15 | hailey
# Processing Record 11 of Set 15 | paciran
# Processing Record 12 of Set 15 | yian
# City not found. Skipping...
# Processing Record 13 of Set 15 | cherdyn
# Processing Record 14 of Set 15 | mossendjo
# Processing Record 15 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 15 | kilrush
# Processing Record 17 of Set 15 | at-bashi
# Processing Record 18 of Set 15 | akonolinga
# Processing Record 19 of Set 15 | camacha
# Processing Record 20 of Set 15 | salinas
# Processing Record 21 of Set 15 | port lincoln
# Processing Record 22 of Set 15 | soure
# Processing Record 23 of Set 15 | ghanzi
# Processing Record 24 of Set 15 | marawi
# Processing Record 25 of Set 15 | yerbogachen
# Processing Record 26 of Set 15 | agadez
# Processing Record 27 of Set 15 | yabelo
# Processing Record 28 of Set 15 | kalmar
# Processing Record 29 of Set 15 | kribi
# Processing Record 30 of Set 15 | imbituba
# Processing Record 31 of Set 15 | tabas
# Processing Record 32 of Set 15 | canto do buriti
# Processing Record 33 of Set 15 | civitavecchia
# Processing Record 34 of Set 15 | clyde river
# Processing Record 35 of Set 15 | harper
# Processing Record 36 of Set 15 | gambela
# Processing Record 37 of Set 15 | vanimo
# Processing Record 38 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 39 of Set 15 | banikoara
# Processing Record 40 of Set 15 | sahuaripa
# Processing Record 41 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 42 of Set 15 | brae
# Processing Record 43 of Set 15 | hoquiam
# Processing Record 44 of Set 15 | bathsheba
# Processing Record 45 of Set 15 | abu dhabi
# Processing Record 46 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 47 of Set 15 | loukhi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# # Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Dikson      RU  73.5069   80.5464    -15.92       100          69
# 1       Butaritari      KI   3.0707  172.7902     83.07        74          85
# 2         Felanitx      ES  39.4696    3.1483     51.01        80          96
# 3         San Luis      AR -33.2950  -66.3356     76.24        49          56
# 4             Biak      ID  -0.9131  122.8766     80.17        79         100
# 5        Busselton      AU -33.6500  115.3333     64.04        53           0
# 6  Bambous Virieux      MU -20.3428   57.7575     78.22        78          20
# 7     Puerto Ayora      EC  -0.7393  -90.3518     69.13        82          55
# 8            Kapaa      US  22.0752 -159.3190     71.92        82          90
# 9         Thompson      CA  55.7435  -97.8558    -20.04        76          20
#
#    Wind Speed    Current Descripton
# 0        3.94         broken clouds
# 1       13.96       overcast clouds
# 2        7.07       overcast clouds
# 3        9.75         broken clouds
# 4        0.43       overcast clouds
# 5       18.63             clear sky
# 6        5.75            few clouds
# 7        8.61         broken clouds
# 8        6.91  heavy intensity rain
# 9        6.91            few clouds

# %%
# #Create an output 
# output_data_file = 'weather_database/Weather_database.csv'

#explort
city_data_df.to_csv('weather_database/Weather_database.csv', index_label="City_ID")
